# %%
from mpasanalysis import *
from e3sm_simulations import *

# %%
# get paths of restart files, monthly mean output files, processed climatology files and output figures
ts_yr0 = 21
ts_yr1 = 30
plt_yr0 = 21
plt_yr1 = 30
rest_yr = 31
nmon = 12 # 12 for production and 1 for testing
run = E3SMSimulation(database='e3sm_simulations.xml', runname='conus01')
data_root = run.get_path(comp='ocn', climo_yr0=ts_yr0, climo_yr1=ts_yr1,
                         ts_yr0=ts_yr0, ts_yr1=ts_yr1, rest_yr=rest_yr)
rst_root = data_root['rst_root']
mon_root = data_root['mon_root']
fig_root = data_root['fig_root']
rst_file = rst_root+'/mpaso.rst.{:04d}-01-01_00000.nc'.format(rest_yr)

# load mesh
mpasmesh = MPASMesh(filepath=rst_file)

# transect
trnsct = VerticalTransect('Davis Strait')
path0 = mpasmesh.get_shortest_path(trnsct.lon0, trnsct.lat0, trnsct.lon1, trnsct.lat1, npoint_ref=2)

nv = len(path0.idx_vertex)
transport = np.zeros([plt_yr1-plt_yr0+1, nmon, nv])
for i, y in enumerate(np.arange(plt_yr1-plt_yr0+1)+plt_yr0):
    for j, m in enumerate(np.arange(nmon)+1):
        print('{:04d}-{:02d}'.format(y, m))
        mon_file = mon_root+'/mpaso.hist.am.timeSeriesStatsMonthly.{:04d}-{:02d}-01.nc'.format(y, m)
        print(mon_file)
        mpasdata = MPASOData(filepath=mon_file, filepath_mesh=rst_file)
        transport0, dist0 = mpasdata.get_transport_cumulative(path=path0, varname_prefix='timeMonthly_avg_',
                                                              bolus=True)
        transport[i,j,:] = transport0[0]
# dist = dist0
dist = gc_distance(np.array(path0.lon_vertex), np.array(path0.lat_vertex), trnsct.lon0, trnsct.lat0)

# save data
path_transport = fig_root+'/data_transport_LabSea_Davis-Strait_volume.npz'
np.savez(path_transport, transport=transport, distance=dist)
# Out:
# Pre-defined transect 'Davis Strait'.
# Vertex closest to P0: 298.48339 66.45757
# Vertex closest to P1: 305.99791 67.00595
#  - Vertex closest to RefP1: 300.93238 66.66670
#  - Vertex closest to RefP2: 303.48882 66.87045
# 0021-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-01-01.nc
# 0021-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-02-01.nc
# 0021-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-03-01.nc
# 0021-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-04-01.nc
# 0021-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-05-01.nc
# 0021-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-06-01.nc
# 0021-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-07-01.nc
# 0021-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-08-01.nc
# 0021-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-09-01.nc
# 0021-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-10-01.nc
# 0021-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-11-01.nc
# 0021-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0021-12-01.nc
# 0022-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-01-01.nc
# 0022-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-02-01.nc
# 0022-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-03-01.nc
# 0022-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-04-01.nc
# 0022-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-05-01.nc
# 0022-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-06-01.nc
# 0022-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-07-01.nc
# 0022-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-08-01.nc
# 0022-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-09-01.nc
# 0022-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-10-01.nc
# 0022-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-11-01.nc
# 0022-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0022-12-01.nc
# 0023-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-01-01.nc
# 0023-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-02-01.nc
# 0023-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-03-01.nc
# 0023-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-04-01.nc
# 0023-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-05-01.nc
# 0023-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-06-01.nc
# 0023-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-07-01.nc
# 0023-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-08-01.nc
# 0023-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-09-01.nc
# 0023-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-10-01.nc
# 0023-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-11-01.nc
# 0023-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0023-12-01.nc
# 0024-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-01-01.nc
# 0024-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-02-01.nc
# 0024-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-03-01.nc
# 0024-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-04-01.nc
# 0024-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-05-01.nc
# 0024-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-06-01.nc
# 0024-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-07-01.nc
# 0024-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-08-01.nc
# 0024-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-09-01.nc
# 0024-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-10-01.nc
# 0024-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-11-01.nc
# 0024-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0024-12-01.nc
# 0025-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-01-01.nc
# 0025-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-02-01.nc
# 0025-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-03-01.nc
# 0025-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-04-01.nc
# 0025-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-05-01.nc
# 0025-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-06-01.nc
# 0025-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-07-01.nc
# 0025-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-08-01.nc
# 0025-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-09-01.nc
# 0025-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-10-01.nc
# 0025-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-11-01.nc
# 0025-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0025-12-01.nc
# 0026-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-01-01.nc
# 0026-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-02-01.nc
# 0026-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-03-01.nc
# 0026-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-04-01.nc
# 0026-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-05-01.nc
# 0026-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-06-01.nc
# 0026-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-07-01.nc
# 0026-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-08-01.nc
# 0026-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-09-01.nc
# 0026-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-10-01.nc
# 0026-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-11-01.nc
# 0026-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0026-12-01.nc
# 0027-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-01-01.nc
# 0027-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-02-01.nc
# 0027-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-03-01.nc
# 0027-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-04-01.nc
# 0027-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-05-01.nc
# 0027-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-06-01.nc
# 0027-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-07-01.nc
# 0027-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-08-01.nc
# 0027-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-09-01.nc
# 0027-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-10-01.nc
# 0027-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-11-01.nc
# 0027-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0027-12-01.nc
# 0028-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-01-01.nc
# 0028-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-02-01.nc
# 0028-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-03-01.nc
# 0028-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-04-01.nc
# 0028-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-05-01.nc
# 0028-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-06-01.nc
# 0028-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-07-01.nc
# 0028-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-08-01.nc
# 0028-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-09-01.nc
# 0028-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-10-01.nc
# 0028-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-11-01.nc
# 0028-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0028-12-01.nc
# 0029-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-01-01.nc
# 0029-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-02-01.nc
# 0029-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-03-01.nc
# 0029-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-04-01.nc
# 0029-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-05-01.nc
# 0029-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-06-01.nc
# 0029-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-07-01.nc
# 0029-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-08-01.nc
# 0029-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-09-01.nc
# 0029-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-10-01.nc
# 0029-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-11-01.nc
# 0029-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0029-12-01.nc
# 0030-01
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-01-01.nc
# 0030-02
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-02-01.nc
# 0030-03
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-03-01.nc
# 0030-04
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-04-01.nc
# 0030-05
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-05-01.nc
# 0030-06
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-06-01.nc
# 0030-07
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-07-01.nc
# 0030-08
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-08-01.nc
# 0030-09
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-09-01.nc
# 0030-10
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-10-01.nc
# 0030-11
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-11-01.nc
# 0030-12
# /lcrc/group/acme/maltrud/archive/A_WCYC1850_ne30_oNAEC60to30cr8L60v1_anvil01/ocn/hist/mpaso.hist.am.timeSeriesStatsMonthly.0030-12-01.nc

# %%
transport.shape
# Out:
# (10, 12, 84)

# %%
transport_mean = np.mean(transport, axis=0)

# %%
for j in np.arange(30):
    for i in np.arange(1):
        plt.plot(transport[j,i,:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-16f95e0dd192> in <module>
#       1 for j in np.arange(30):
#       2     for i in np.arange(1):
# ----> 3         plt.plot(transport[j,i,:])
#
# IndexError: index 10 is out of bounds for axis 0 with size 10
