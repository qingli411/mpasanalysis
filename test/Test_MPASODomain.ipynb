# %%
import sys
sys.path.append('../')
from mpasanalysis import *
# %matplotlib inline

# %%
mesh_file = '/Users/qingli/data/mpas/test/super-parameterization/output.0000-01-01_00.00.00.nc'
data_file = '/Users/qingli/data/mpas/test/super-parameterization/output.0000-01-01_00.00.00.nc'

# %%
mpas_data = MPASOData(filepath=data_file, filepath_mesh=mesh_file)

# %% [markdown]
# ### plot mesh

# %%
fig = plt.figure(figsize=[10,10])
mpas_data.mesh.plot_edges_xy(linewidths=1, colors='gray')
plt.xlim([0, 10000])
plt.ylim([20000, 30000])
# Out:
# (20000, 30000)

# %% [markdown]
# ### plot temperature

# %%
temp = mpas_data.get_domain(varname='temperature', position='cell', name='temperature', units='degC', tidx=-1)
# Out:
# Reading mesh data from /Users/qingli/data/mpas/test/super-parameterization/output.0000-01-01_00.00.00.nc

# %%
fig = plt.figure(figsize=[12,10])
temp.plot_xy()
# temp.plot_xy(ptype='contourf')
# plt.xlim([0, 10000])
# plt.ylim([20000, 30000])

# %% [markdown]
# ### plot relative vorticity

# %%
vorticity = mpas_data.get_domain(varname='relativeVorticityCell', position='cell',
                                 name='relative vorticity', units='1/s', tidx=-1, zidx=1)
# Out:
# Reading mesh data from /Users/qingli/data/mpas/test/super-parameterization/output.0000-01-01_00.00.00.nc

# %%
fig = plt.figure(figsize=[12,10])
vorticity.plot_xy() 
# vort.plot_xy(ptype='contourf') 
# plt.xlim([0, 15000])
# plt.ylim([20000, 35000])
