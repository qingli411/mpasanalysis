# %%
import sys
from netCDF4 import chartostring
from mpasanalysis import *
# %matplotlib inline

# %%
# mesh_file = '/Users/qingli/data/mpas/test/super-parameterization/sp_sc/output_kpp.0001-01-01_00.00.00.nc'
mesh_file = '/Users/qingli/data/mpas/test/super-parameterization/sp_sc/KPP_test.0001-01-01_00.00.00.nc'
data_file = mesh_file

# %%
mpas_data = MPASOData(filepath=data_file, filepath_mesh=mesh_file)

# %% [markdown]
# ### plot temperature

# %%
temp = mpas_data.get_domain(varname='temperatureLES', position='cellLES', name='temperature', units='degC', tidx=-1)
# Out:
# Reading mesh data from /Users/qingli/data/mpas/test/super-parameterization/sp_sc/KPP_test.0001-01-01_00.00.00.nc

# %%
xfrac = 0.5
yfrac = 0.5

# %%
fig = plt.figure(figsize=[12,10])
# levels=np.linspace(18,20,51)
temp.plot_xy()
plt.xlim([-50000, 500000])
plt.ylim([-50000, 500000])
# Out:
# (-50000, 500000)

# %%
temp.plot_yz(xfrac=5, ptype='contourf')
# plt.ylim([-100, 0])
# Out:
# Nearest neighbor interpolation to 3 points.

# %%
temp_pfl = mpas_data.get_profile(varname='temperatureLES', idx=0, position='cellLES', name='temperature', units='degC',
                                 tidx_start=0, tidx_end=None)

# %%
temp_pfl.plot()
plt.ylim([-100, 0])
plt.gcf().autofmt_xdate()

# %%
temp_pfl.plot_mean()
plt.ylim([-100, 0])
# plt.xlim([19, 20])
# Out:
# (-100, 0)

# %%
temp_pfl.z
# Out:
# masked_array(data=[-232.82990349, -208.40515087, -186.4483447 ,
#                    -166.71011665, -148.96629529, -133.01536009,
#                    -118.67615274, -105.78581967,  -94.19796251,
#                     -83.78097538,  -74.41655025,  -65.99833327,
#                     -58.43071686,  -51.62775393,  -45.51218172,
#                     -40.01454432,  -35.07240383,  -30.62963126,
#                     -26.63576907,  -23.04545807,  -19.81792231,
#                     -16.91650593,  -14.30825692,  -11.9635528 ,
#                      -9.85576425,   -7.96095265,   -6.2575982 ,
#                      -4.72635553,   -3.34983397,   -2.11240007,
#                      -1.        ,    0.        ],
#              mask=False,
#        fill_value=1e+20)
